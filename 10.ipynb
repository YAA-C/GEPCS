# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("auto0-20231226-141335-673928667-de_mirage-_cz__siddhesh_game_server-430591.csv")
df.head(5)
# Out:
#    currentTick      playerId          X          Y         Z  deltaX  deltaY  \
# 0          0.0  7.656120e+16 -1111.3384 -2445.9138 -95.96875     0.0     0.0
# 1          1.0  7.656120e+16 -1111.3384 -2445.9138 -95.96875     0.0     0.0
# 2          3.0  7.656120e+16 -1111.3384 -2445.9138 -95.96875     0.0     0.0
# 3          4.0  7.656120e+16 -1111.3384 -2445.9138 -95.96875     0.0     0.0
# 4          5.0  7.656120e+16 -1111.3384 -2445.9138 -95.96875     0.0     0.0
#
#    deltaZ       yaw    pitch  ...  distToTarget  targetHitArea  \
# 0     0.0  34.85962  2.48291  ...           NaN            NaN
# 1     0.0  34.85962  2.48291  ...           NaN            NaN
# 2     0.0  34.85962  2.48291  ...           NaN            NaN
# 3     0.0  34.85962  2.48291  ...           NaN            NaN
# 4     0.0  34.85962  2.48291  ...           NaN            NaN
#
#    penetratedObject  weaponUsed  weaponCategory isScoping  isTargetBlind  \
# 0               NaN         NaN             NaN       NaN            NaN
# 1               NaN         NaN             NaN       NaN            NaN
# 2               NaN         NaN             NaN       NaN            NaN
# 3               NaN         NaN             NaN       NaN            NaN
# 4               NaN         NaN             NaN       NaN            NaN
#
#    isTargetInSmoke  targetReturnedDmg  Label
# 0              NaN                NaN  False
# 1              NaN                NaN  False
# 2              NaN                NaN  False
# 3              NaN                NaN  False
# 4              NaN                NaN  False
#
# [5 rows x 38 columns]

# %%
def count_blind_shots(dataframe):
  
    filtered_data = dataframe[dataframe['isTargetBlind'].notna() & dataframe['isTargetBlind']]

    
    blind_shot_count = len(filtered_data)

    return blind_shot_count



blind_shot_count = count_blind_shots(df)

print(f"Number of times the target player was blind and shot landed on the target: {blind_shot_count}")
# Out:
# Number of times the target player was blind and shot landed on the target: 0
